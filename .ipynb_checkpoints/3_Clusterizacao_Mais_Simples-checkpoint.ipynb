# %% [markdown]
# ## OBJETIVO DO TRABALHO
#
#     Desenvolvimento de uma segmentação de clientes para definir a estratégia de marketing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import Normalizer

# %% [markdown]
# # Análise exploratória dos dados

# %%
#Importação dos dados
df0 = pd.read_csv('clientes_agrupados.csv')

# %%
#Retornando as primeiras linhas do DataFrame
df0.head()
# Out:
#    cod_cliente  valor_total  numero_visitas  quantidade_produtos  \
# 0        10000         2069              46                  214
# 1        10001         9110             200                 1111
# 2        10002           76               2                    2
# 3        10006         8883             153                 1087
# 4        10007         9072             119                 1289
#
#    dias_desde_ultima_compra
# 0                         4
# 1                         8
# 2                       370
# 3                       350
# 4                         2

# %% [markdown]
# #### Verificando os tipos

# %%
df0.dtypes
# Out:
# cod_cliente                 int64
# valor_total                 int64
# numero_visitas              int64
# quantidade_produtos         int64
# dias_desde_ultima_compra    int64
# dtype: object

# %% [markdown]
# #### Ajustando a coluna cod_cliente para ser não numérica

# %%
df0['cod_cliente'] = df0['cod_cliente'].astype('string')

# %%
#Verificando se foi alterado
df0.dtypes
# Out:
# cod_cliente                 string
# valor_total                  int64
# numero_visitas               int64
# quantidade_produtos          int64
# dias_desde_ultima_compra     int64
# dtype: object

# %% [markdown]
# #### Verificando o Resumo Estatístico

# %%
colunas_numericas = df0.select_dtypes(include=['int64', 'float64'])
colunas_numericas.describe(percentiles=[0.25, 0.5, 0.75])
# Out:
#          valor_total  numero_visitas  quantidade_produtos  \
# count   53170.000000    53170.000000         53170.000000
# mean     2246.389487       30.967068           264.899680
# std      4146.176503       52.303246           496.771878
# min         0.000000        1.000000             1.000000
# 25%       182.000000        3.000000            18.000000
# 50%       714.000000       10.000000            75.000000
# 75%      2448.000000       36.000000           280.000000
# max    111717.000000     1572.000000         10059.000000
#
#        dias_desde_ultima_compra
# count              53170.000000
# mean                 159.235415
# std                  270.850289
# min                    2.000000
# 25%                    7.000000
# 50%                   28.000000
# 75%                  192.000000
# max                 1521.000000

# %% [markdown]
# #### Porcentagem de valores ausentes

# %%
(df0.isna().sum() / len(df0))*100
# Out:
# cod_cliente                 0.0
# valor_total                 0.0
# numero_visitas              0.0
# quantidade_produtos         0.0
# dias_desde_ultima_compra    0.0
# dtype: float64

# %% [markdown]
# # Preparação e limpeza dos dados

# %% [markdown]
# ## Remoção de Outliers

# %%
df1 = df0.copy()

# %% [markdown]
# ##### Método do std(Desvio Padrão) - Valor Total

# %%
dt_mean, dt_std = np.mean(df1['valor_total']), np.std(df1['valor_total'])
cut_off = dt_std * 3
lower, upper = dt_mean - cut_off, dt_mean + cut_off
idx = np.where((df1['valor_total'] < lower) | (df1['valor_total'] > upper))

# %%
plt.scatter(df1['dias_desde_ultima_compra'],df1['valor_total'], color='blue')

#Marcando os outliers
plt.scatter(df1.loc[idx, 'dias_desde_ultima_compra'], df1.loc[idx, 'valor_total'], color= 'red')

#Títulos e rótulos
plt.title('Método do Desvio')
plt.xlabel('Valor Total')
plt.ylabel('Dias Desde a Última Compra')

#Exibindo o gráfico
plt.show()

# %% [markdown]
# #### Novo DataFrame sem os outliers identificados

# %%
df2 = df1.loc[idx]

# %%
# Criar o gráfico de dispersão para a variável valor_total com os outliers removidos
plt.scatter(df2['valor_total'], df2['dias_desde_ultima_compra'], color='blue')

# Adicionar títulos e rótulos de eixo
plt.title('Gráfico de dispersão de valor_total x dias_desde_ultima_compra (sem outliers)')
plt.xlabel('valor_total')
plt.ylabel('dias_desde_ultima_compra')

# Exibir o gráfico
plt.show()

# %% [markdown]
# ### Descobrindo o número ideal de cluster

# %%
df3 = df2.copy()

# %%
#Selecionando as colunas de relevância
X = df3[['valor_total','dias_desde_ultima_compra']]

# %%
#Padronizando os dados
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled
# Out:
# array([[ 0.06236362, -0.19537527],
#        [-0.81198336,  0.15077874],
#        [-0.34922609, -0.18095218],
#        ...,
#        [-0.56570428, -0.13768293],
#        [-0.6912054 , -0.1665291 ],
#        [-0.16772177, -0.18095218]])

# %%
#Intânciando o modelo
kmeans = KMeans()

#Criando uma visualiação do cotovelo usando o KElbowVisualizer
visualizador = KElbowVisualizer(kmeans, k=(2,15))
visualizador.fit(X_scaled)

#Mostrando a visualização
visualizador.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Avaliando a qualidade do cluster

# %%
df4 = df3.copy()

# %%
df4 = df4.reset_index(drop=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Normalizar os dados
normalizer = Normalizer()
X_normalized = normalizer.fit_transform(X)

# Aplicar a transformação PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_normalized)

# Escolher o número de clusters
k = 6

# Realizar o agrupamento com o algoritmo K-Means
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_pca)

# Adicionar as etiquetas de cluster ao DataFrame original
df4['cluster'] = kmeans.labels_

# Avaliar a qualidade dos clusters usando o índice de silhueta
silhouette_avg = silhouette_score(X_pca, kmeans.labels_)
print("Índice de silhueta médio:", silhouette_avg)

# Plotar um gráfico de dispersão para visualizar os clusters
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df4['cluster'])
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Gráfico de dispersão dos clusters após a transformação PCA')
plt.show()
# Out:
# Índice de silhueta médio: 0.8763062339011181

# %%
df4
# Out:
#      cod_cliente  valor_total  numero_visitas  quantidade_produtos  \
# 0          10014        22693             377                 2993
# 1          10031        14918             162                 2004
# 2          10068        19033             147                 3010
# 3          10072        16146             102                 2669
# 4          10073        18333             116                 2291
# ...          ...          ...             ...                  ...
# 1136        9860        15696             152                 1890
# 1137        9867        23075             380                 3218
# 1138        9887        17108             325                 2335
# 1139        9971        15992             164                 2093
# 1140        9982        20647             246                 3155
#
#       dias_desde_ultima_compra  cluster
# 0                            2        0
# 1                           26        5
# 2                            3        0
# 3                            4        0
# 4                            2        0
# ...                        ...      ...
# 1136                         5        0
# 1137                         4        0
# 1138                         6        0
# 1139                         4        0
# 1140                         3        0
#
# [1141 rows x 6 columns]

# %% [markdown]
# # Clientes por Cluster

# %%
# Imprimir os valores agrupados por cluster
clusters_status = df4.groupby('cluster').agg({
    'valor_total'    : ['count', 'mean', 'std', 'min', 'max'],
    'numero_visitas' : ['count', 'mean', 'std', 'min', 'max'],
    'quantidade_produtos' : ['count', 'mean', 'std', 'min', 'max'],
    'dias_desde_ultima_compra' : ['count', 'mean', 'std', 'min', 'max'] 
})

#Renomear as colunas
clusters_status.columns = ['_'.join(col).strip() for col in clusters_status.columns.values]

clusters_status
# Out:
#          valor_total_count  valor_total_mean  valor_total_std  \
# cluster
# 0                     1073      22275.542404      9014.217285
# 1                        7      19027.857143      2573.442081
# 2                        2      16775.500000      1591.697364
# 3                       10      20419.800000      7389.805076
# 4                       12      21970.666667      5215.418458
# 5                       37      19559.783784      7192.747459
#
#          valor_total_min  valor_total_max  numero_visitas_count  \
# cluster
# 0                  14693           111717                  1073
# 1                  15730            21911                     7
# 2                  15650            17901                     2
# 3                  15880            40616                    10
# 4                  15692            33676                    12
# 5                  14721            46215                    37
#
#          numero_visitas_mean  numero_visitas_std  numero_visitas_min  \
# cluster
# 0                 225.083877          121.205637                  15
# 1                 200.285714           50.215251                 170
# 2                 132.000000           36.769553                 106
# 3                 156.800000          104.281457                  33
# 4                 206.750000           86.068815                  78
# 5                 138.243243           96.566444                  12
#
#          numero_visitas_max  quantidade_produtos_count  \
# cluster
# 0                      1572                       1073
# 1                       313                          7
# 2                       158                          2
# 3                       368                         10
# 4                       361                         12
# 5                       405                         37
#
#          quantidade_produtos_mean  quantidade_produtos_std  \
# cluster
# 0                     2567.493010              1016.496388
# 1                     2192.857143               308.533860
# 2                     2103.500000               130.814755
# 3                     2574.800000               631.303554
# 4                     2383.916667               605.175475
# 5                     1990.756757               913.064298
#
#          quantidade_produtos_min  quantidade_produtos_max  \
# cluster
# 0                             99                    10059
# 1                           1860                     2591
# 2                           2011                     2196
# 3                           1524                     3787
# 4                           1775                     3829
# 5                             52                     4504
#
#          dias_desde_ultima_compra_count  dias_desde_ultima_compra_mean  \
# cluster
# 0                                  1073                       4.839702
# 1                                     7                     590.000000
# 2                                     2                     928.500000
# 3                                    10                     311.400000
# 4                                    12                     162.750000
# 5                                    37                      40.297297
#
#          dias_desde_ultima_compra_std  dias_desde_ultima_compra_min  \
# cluster
# 0                            3.450399                             2
# 1                           78.900782                           482
# 2                          154.856385                           819
# 3                          101.353288                           223
# 4                           61.997251                            85
# 5                           22.451014                            18
#
#          dias_desde_ultima_compra_max
# cluster
# 0                                  49
# 1                                 672
# 2                                1038
# 3                                 579
# 4                                 282
# 5                                 101

# %% [markdown]
# ### Plotando

# %%
cluster_counts = df4['cluster'].value_counts()

# Plotar um gráfico de barras
cluster_counts.plot(kind='bar')
plt.xlabel('Cluster')
plt.ylabel('Quantidade de clientes')
plt.title('Segmentação de clientes por cluster')
#plt.show()

#Iterando sobre as barras e adicionando o valor exato acima das mesmas
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.0f}',
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center',
                       va='center',
                       size=12,
                       xytext=(0,8),
                       textcoords='offset points')

plt.show()

# %%
# Criar um gráfico de segmentação
sns.countplot(x='cluster', data=df4)
plt.xlabel('Cluster')
plt.ylabel('Quantidade de clientes')
plt.title('Segmentação de clientes por cluster')

#Iterando sobre as barras e adicionando o valor exato acima das mesmas
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.0f}',
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center',
                       va='center',
                       size=12,
                       xytext=(0, 8),
                       textcoords='offset points')

plt.show()

# %%
# Realizando a Clusterização sem Outliers
df5 = df0.copy()

# %%
#Dados estatísticos
df5.describe()
# Out:
#          valor_total  numero_visitas  quantidade_produtos  \
# count   53170.000000    53170.000000         53170.000000
# mean     2246.389487       30.967068           264.899680
# std      4146.176503       52.303246           496.771878
# min         0.000000        1.000000             1.000000
# 25%       182.000000        3.000000            18.000000
# 50%       714.000000       10.000000            75.000000
# 75%      2448.000000       36.000000           280.000000
# max    111717.000000     1572.000000         10059.000000
#
#        dias_desde_ultima_compra
# count              53170.000000
# mean                 159.235415
# std                  270.850289
# min                    2.000000
# 25%                    7.000000
# 50%                   28.000000
# 75%                  192.000000
# max                 1521.000000

# %%
#Selecionando as colunas de relevância
X5 = df5[['valor_total','dias_desde_ultima_compra']]

#Normalizando
scaler_5 = MinMaxScaler()
X_scaled_5 = scaler_5.fit_transform(X5)

#Intânciando o modelo
kmeans_5 = KMeans()

#Criando uma visualiação do cotovelo usando o KElbowVisualizer
visualizador_5 = KElbowVisualizer(kmeans_5, k=(2,20))
visualizador_5.fit(X_scaled_5)

#Mostrando a visualização
visualizador_5.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
df6 = df5.reset_index(drop=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
#Normalizando os dados
normalizador_5 = Normalizer()
X_normalizado_5 = normalizador_5.fit_transform(X5)

#Aplicar a transformação de PCA
pca = PCA(n_components=2)
X_pca_5 = pca.fit_transform(X_normalizado_5)

# Escolher o número de clusters
k = 6

#Realizar o agrupamento com K-means
kmeans_5 = KMeans(n_clusters=k, random_state=42, init='k-means++')
kmeans_5.fit(X_pca_5)

# Adicionar as etiquetas de cluster ao DataFrame original
df6['cluster'] = kmeans_5.labels_

#Avaliar a qualidade dos clusters usando o índice de silhueta
silhouette_avg_5 = silhouette_score(X_pca_5, kmeans_5.labels_)
print('Índice de silhueta médio: {}'.format(silhouette_avg_5))

#Plotando o gráfico de dispersão praa visualizar os clusters
plt.scatter(X_pca_5[:,0], X_pca_5[:,1], c=df6['cluster'])
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Gráfico de dispersão dos clusters após a transformação PCA')
plt.show()
# Out:
# Índice de silhueta médio: 0.7262038243314524

# %%
#Clientes por cluster
cluster_status_5 = df6.groupby('cluster').agg({
    'valor_total'    : ['count', 'mean', 'std', 'min', 'max'],
    'numero_visitas' : ['count', 'mean', 'std', 'min', 'max'],
    'quantidade_produtos' : ['count', 'mean', 'std', 'min', 'max'],
    'dias_desde_ultima_compra' : ['count', 'mean', 'std', 'min', 'max']
})

cluster_status_5.columns = ['_'.join(col).strip() for col in cluster_status_5.columns.values]

cluster_status_5
# Out:
#          valor_total_count  valor_total_mean  valor_total_std  \
# cluster
# 0                    31071       3611.263397      4970.851069
# 1                     6258         66.705657        54.860047
# 2                     3043        283.612225       258.902047
# 3                     3435        425.137991       457.428961
# 4                     3714        170.390953       130.421988
# 5                     5649        683.538148       917.812589
#
#          valor_total_min  valor_total_max  numero_visitas_count  \
# cluster
# 0                     27           111717                 31071
# 1                      0              396                  6258
# 2                      4             1825                  3043
# 3                      3             3359                  3435
# 4                      1              939                  3714
# 5                      7             9785                  5649
#
#          numero_visitas_mean  numero_visitas_std  numero_visitas_min  \
# cluster
# 0                  49.417656           61.701147                   1
# 1                   1.521732            1.153376                   1
# 2                   4.341768            5.270418                   1
# 3                   6.354294            7.997703                   1
# 4                   2.806947            3.083565                   1
# 5                   9.926713           14.152171                   1
#
#          numero_visitas_max  quantidade_produtos_count  \
# cluster
# 0                      1572                      31071
# 1                        16                       6258
# 2                        44                       3043
# 3                        92                       3435
# 4                        33                       3714
# 5                       201                       5649
#
#          quantidade_produtos_mean  quantidade_produtos_std  \
# cluster
# 0                      426.540633               596.031102
# 1                        8.068552                 8.436410
# 2                       31.869208                40.632200
# 3                       48.408443                66.490969
# 4                       19.173129                21.185633
# 5                       79.077536               126.916294
#
#          quantidade_produtos_min  quantidade_produtos_max  \
# cluster
# 0                              1                    10059
# 1                              1                       87
# 2                              1                      377
# 3                              1                      693
# 4                              1                      258
# 5                              1                     1449
#
#          dias_desde_ultima_compra_count  dias_desde_ultima_compra_mean  \
# cluster
# 0                                 31071                      22.629011
# 1                                  6258                     609.391659
# 2                                  3043                     301.323365
# 3                                  3435                     223.662300
# 4                                  3714                     392.710824
# 5                                  5649                     142.703664
#
#          dias_desde_ultima_compra_std  dias_desde_ultima_compra_min  \
# cluster
# 0                           49.554385                             2
# 1                          356.850961                             4
# 2                          266.820935                             4
# 3                          234.791141                             2
# 4                          282.546911                             3
# 5                          186.976960                             2
#
#          dias_desde_ultima_compra_max
# cluster
# 0                                1042
# 1                                1521
# 2                                1512
# 3                                1469
# 4                                1518
# 5                                1382

# %%
#Plotando
cluster_counts_5 = df6['cluster'].value_counts()

# Plotar um gráfico de barras
cluster_counts_5.plot(kind='bar')
plt.xlabel('Cluster')
plt.ylabel('Quantidade de clientes')
plt.title('Segmentação de clientes por cluster')
#plt.show()

#Iterando sobre as barras e adicionando o valor exato acima das mesmas
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.0f}',
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center',
                       va='center',
                       size=12,
                       xytext=(0,8),
                       textcoords='offset points')

plt.show()

# %%
df6
# Out:
#       cod_cliente  valor_total  numero_visitas  quantidade_produtos  \
# 0           10000         2069              46                  214
# 1           10001         9110             200                 1111
# 2           10002           76               2                    2
# 3           10006         8883             153                 1087
# 4           10007         9072             119                 1289
# ...           ...          ...             ...                  ...
# 53165        9992         1867              17                  145
# 53166        9995         4154              68                  661
# 53167        9997         5229              74                  397
# 53168        9998         2767              41                  403
# 53169        9999         1114               9                   53
#
#        dias_desde_ultima_compra  cluster
# 0                             4        0
# 1                             8        0
# 2                           370        1
# 3                           350        0
# 4                             2        0
# ...                         ...      ...
# 53165                        51        0
# 53166                        12        0
# 53167                         6        0
# 53168                         3        0
# 53169                       174        5
#
# [53170 rows x 6 columns]

# %% [markdown]
# # Exportando para Arquivo

# %%
df5.to_csv('clientes_clusterizados_sem_outliers.csv')

# %%
df6.to_csv('clientes_clusterizados_com_outliers.csv')
